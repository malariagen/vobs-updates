# %% [raw]
# ---
# layout: post
# title: "Terms of use metadata"
# tags: data
# ---

# %%
import sys
sys.version_info
# Out:
# sys.version_info(major=3, minor=12, micro=5, releaselevel='final', serial=0)

# %% [markdown]
# Some new metadata columns have been added to help identify which sample sets have usage restrictions (e.g., publication embargo) and which are available for unrestricted use. The metadata columns are:
#
# * `terms_of_use_expiry_date` - Gives the date on which any terms of use will expire. After this date, there will be no usage restrictions on data relating to the sample set.
# * `terms_of_use_url` - Gives the address of a web page that describes any usage restrictions which apply to the sample set.
#
# If the value of either of these fields is empty then there are no terms of use applying to the sample set.
#
# These new metadata columns can be accessed via the `malariagen_data` Python API. The API also addes an additional computed field:
#
# * `unrestricted_use` - This is a computed column which is added for convenience. The value is `True` if the terms of use have expired, or if there were never any usage restrictions applied.
#
# The metadata columns are available in the dataframes returned by the `sample_sets()` and `sample_metadata()` functions. Below are some examples for data from the *Anopheles gambiae* complex accessed via the `Ag3` API. Similar code can be used for *Anopheles funestus* samples via the `Af1` API.

# %%
import malariagen_data
ag3 = malariagen_data.Ag3()

# %%
malariagen_data.__version__  # diagnostics
# Out:
# '13.0.0'

# %%
ag3  # diagnostics
# Out:
# <MalariaGEN Ag3 API client>
# Storage URL             : gs://vo_agam_release_master_us_central1/
# Data releases available : 3.0, 3.1, 3.2, 3.3, 3.4, 3.5, 3.6, 3.7, 3.8, 3.9, 3.10
# Results cache           : None
# Cohorts analysis        : 20240717
# AIM analysis            : 20220528
# Site filters analysis   : dt_20200416
# Software version        : malariagen_data 13.0.0
# Client location         : England, United Kingdom
# ---
# Please note that data are subject to terms of use,
# for more information see https://www.malariagen.net/data
# or contact support@malariagen.net. For API documentation see
# https://malariagen.github.io/malariagen-data-python/v13.0.0/Ag3.html

# %%
ag3._show_progress = False  # for the blog post, avoid progress outputs

# %% [markdown]
# Sample set metadata:

# %%
df_sample_sets = ag3.sample_sets()
df_sample_sets[["sample_set", "terms_of_use_expiry_date", "unrestricted_use"]]
# Out:
#                         sample_set terms_of_use_expiry_date  unrestricted_use
# 0                       AG1000G-AO               2025-01-01             False
# 1                     AG1000G-BF-A               2025-01-01             False
# 2                     AG1000G-BF-B               2025-01-01             False
# 3                     AG1000G-BF-C               2025-01-01             False
# 4                       AG1000G-CD               2025-01-01             False
# ..                             ...                      ...               ...
# 78        1323-VO-GM-NGWA-VMF00235               2026-04-09             False
# 79        1323-VO-GM-NGWA-VMF00242               2026-04-09             False
# 80  1329-VO-GA-CHRISTOPHE-VMF00228               2026-04-09             False
# 81                     bergey-2019                      NaN              True
# 82                     campos-2021                      NaN              True
#
# [83 rows x 3 columns]

# %% [markdown]
# Query to find sample sets with no usage restrictions:

# %%
df_sample_sets.query("unrestricted_use")
# Out:
#                        sample_set  sample_count               study_id  \
# 32          fontaine-2015-rebuild            72  fontaine-2015-rebuild
# 34  1237-VO-BJ-DJOGBENOU-VMF00050            90   1237-VO-BJ-DJOGBENOU
# 35  1237-VO-BJ-DJOGBENOU-VMF00067           142   1237-VO-BJ-DJOGBENOU
# 36     1244-VO-GH-YAWSON-VMF00051           666      1244-VO-GH-YAWSON
# 37   1245-VO-CI-CONSTANT-VMF00054            38    1245-VO-CI-CONSTANT
# 38  1253-VO-TG-DJOGBENOU-VMF00052           179   1253-VO-TG-DJOGBENOU
# 39  1178-VO-UG-LAWNICZAK-VMF00025            57   1178-VO-UG-LAWNICZAK
# 65                    barron-2019             4            barron-2019
# 66                  crawford-2016            25          crawford-2016
# 72                 tennessen-2021           208         tennessen-2021
# 81                    bergey-2019           113            bergey-2019
# 82                    campos-2021           163            campos-2021
#
#                                             study_url  \
# 32            https://doi.org/10.1126/science.1258524
# 34  https://www.malariagen.net/partner_study/1237-...
# 35  https://www.malariagen.net/partner_study/1237-...
# 36  https://www.malariagen.net/partner_study/1244-...
# 37  https://www.malariagen.net/partner_study/1245-...
# 38  https://www.malariagen.net/partner_study/1253-...
# 39  https://www.malariagen.net/partner_study/1178-...
# 65         https://doi.org/10.1038/s41598-019-49065-5
# 66                  https://doi.org/10.1111/mec.13572
# 72                  https://doi.org/10.1111/mec.15756
# 81                  https://doi.org/10.1111/eva.12878
# 82  https://doi.org/10.1038/s42003-021-02168-0, ht...
#
#    terms_of_use_expiry_date  \
# 32                      NaN
# 34               2024-07-22
# 35               2024-07-22
# 36               2024-07-22
# 37               2024-07-22
# 38               2024-07-22
# 39               2023-10-26
# 65                      NaN
# 66                      NaN
# 72                      NaN
# 81                      NaN
# 82                      NaN
#
#                                      terms_of_use_url release  \
# 32  https://www.science.org/doi/10.1126/science.12...    3.10
# 34  https://malariagen.github.io/vector-data/ag3/a...     3.2
# 35  https://malariagen.github.io/vector-data/ag3/a...     3.2
# 36  https://malariagen.github.io/vector-data/ag3/a...     3.2
# 37  https://malariagen.github.io/vector-data/ag3/a...     3.2
# 38  https://malariagen.github.io/vector-data/ag3/a...     3.2
# 39  https://malariagen.github.io/vector-data/ag3/a...     3.3
# 65  https://www.nature.com/articles/s41598-019-490...     3.7
# 66  https://onlinelibrary.wiley.com/doi/10.1111/me...     3.7
# 72  https://onlinelibrary.wiley.com/doi/10.1111/me...     3.8
# 81  https://onlinelibrary.wiley.com/doi/10.1111/ev...     3.9
# 82  https://www.nature.com/articles/s42003-021-021...     3.9
#
#     unrestricted_use
# 32              True
# 34              True
# 35              True
# 36              True
# 37              True
# 38              True
# 39              True
# 65              True
# 66              True
# 72              True
# 81              True
# 82              True

# %% [markdown]
# Sample metadata:

# %%
df_samples = ag3.sample_metadata()
df_samples[["sample_id", "sample_set", "terms_of_use_expiry_date", "terms_of_use_url", "unrestricted_use"]]
# Out:
#                       sample_id                   sample_set  \
# 0      VBS00256-4651STDY7017184  1177-VO-ML-LEHMANN-VMF00004
# 1      VBS00257-4651STDY7017185  1177-VO-ML-LEHMANN-VMF00004
# 2      VBS00259-4651STDY7017186  1177-VO-ML-LEHMANN-VMF00004
# 3      VBS00262-4651STDY7017187  1177-VO-ML-LEHMANN-VMF00004
# 4      VBS00277-4651STDY7017189  1177-VO-ML-LEHMANN-VMF00004
# ...                         ...                          ...
# 19766              SAMN15222632               tennessen-2021
# 19767              SAMN15222633               tennessen-2021
# 19768              SAMN15222634               tennessen-2021
# 19769              SAMN15222635               tennessen-2021
# 19770              SAMN15222636               tennessen-2021
#
#       terms_of_use_expiry_date  \
# 0                   2025-11-17
# 1                   2025-11-17
# 2                   2025-11-17
# 3                   2025-11-17
# 4                   2025-11-17
# ...                        ...
# 19766                      NaN
# 19767                      NaN
# 19768                      NaN
# 19769                      NaN
# 19770                      NaN
#
#                                         terms_of_use_url  unrestricted_use
# 0      https://malariagen.github.io/vector-data/ag3/a...             False
# 1      https://malariagen.github.io/vector-data/ag3/a...             False
# 2      https://malariagen.github.io/vector-data/ag3/a...             False
# 3      https://malariagen.github.io/vector-data/ag3/a...             False
# 4      https://malariagen.github.io/vector-data/ag3/a...             False
# ...                                                  ...               ...
# 19766  https://onlinelibrary.wiley.com/doi/10.1111/me...              True
# 19767  https://onlinelibrary.wiley.com/doi/10.1111/me...              True
# 19768  https://onlinelibrary.wiley.com/doi/10.1111/me...              True
# 19769  https://onlinelibrary.wiley.com/doi/10.1111/me...              True
# 19770  https://onlinelibrary.wiley.com/doi/10.1111/me...              True
#
# [19771 rows x 5 columns]

# %% [markdown]
# Query to find samples with no usage restrictions:

# %%
df_samples.query("unrestricted_use")
# Out:
#                       sample_id partner_sample_id      contributor  \
# 670    VBS10116-4954STDY7089644     UG4A2016A1_96   Mara Lawniczak
# 671    VBS10117-4954STDY7089645     UG4A2016B1_95   Mara Lawniczak
# 672    VBS10118-4954STDY7089646     UG4A2016C1_94   Mara Lawniczak
# 673    VBS10119-4954STDY7089647     UG4A2016D1_93   Mara Lawniczak
# 674    VBS10120-4954STDY7089648     UG4A2016E1_92   Mara Lawniczak
# ...                         ...               ...              ...
# 19766              SAMN15222632              D342  Jacob Tennessen
# 19767              SAMN15222633              D343  Jacob Tennessen
# 19768              SAMN15222634              D346  Jacob Tennessen
# 19769              SAMN15222635              D347  Jacob Tennessen
# 19770              SAMN15222636              D348  Jacob Tennessen
#
#             country  location  year  month  latitude  longitude sex_call  ...  \
# 670          Uganda     Busia  2013      1     0.466     34.089        F  ...
# 671          Uganda     Busia  2016      6     0.466     34.089        F  ...
# 672          Uganda     Busia  2016      6     0.466     34.089        F  ...
# 673          Uganda     Busia  2016      6     0.466     34.089        F  ...
# 674          Uganda     Busia  2016      6     0.466     34.089        F  ...
# ...             ...       ...   ...    ...       ...        ...      ...  ...
# 19766  Burkina Faso  Tengrela  2016     -1    10.700     -4.800        F  ...
# 19767  Burkina Faso  Tengrela  2016     -1    10.700     -4.800        F  ...
# 19768  Burkina Faso  Tengrela  2016     -1    10.700     -4.800        F  ...
# 19769  Burkina Faso  Tengrela  2016     -1    10.700     -4.800        F  ...
# 19770  Burkina Faso  Tengrela  2016     -1    10.700     -4.800        F  ...
#
#           admin1_name admin1_iso  admin2_name     taxon cohort_admin1_year  \
# 670    Eastern Region       UG-E        Busia   gambiae     UG-E_gamb_2013
# 671    Eastern Region       UG-E        Busia   gambiae     UG-E_gamb_2016
# 672    Eastern Region       UG-E        Busia   gambiae     UG-E_gamb_2016
# 673    Eastern Region       UG-E        Busia   gambiae     UG-E_gamb_2016
# 674    Eastern Region       UG-E        Busia   gambiae     UG-E_gamb_2016
# ...               ...        ...          ...       ...                ...
# 19766        Cascades      BF-02        Comoe  coluzzii    BF-02_colu_2016
# 19767        Cascades      BF-02        Comoe  coluzzii    BF-02_colu_2016
# 19768        Cascades      BF-02        Comoe  coluzzii    BF-02_colu_2016
# 19769        Cascades      BF-02        Comoe  coluzzii    BF-02_colu_2016
# 19770        Cascades      BF-02        Comoe  coluzzii    BF-02_colu_2016
#
#       cohort_admin1_month cohort_admin1_quarter     cohort_admin2_year  \
# 670     UG-E_gamb_2013_01     UG-E_gamb_2013_Q1   UG-E_Busia_gamb_2013
# 671     UG-E_gamb_2016_06     UG-E_gamb_2016_Q2   UG-E_Busia_gamb_2016
# 672     UG-E_gamb_2016_06     UG-E_gamb_2016_Q2   UG-E_Busia_gamb_2016
# 673     UG-E_gamb_2016_06     UG-E_gamb_2016_Q2   UG-E_Busia_gamb_2016
# 674     UG-E_gamb_2016_06     UG-E_gamb_2016_Q2   UG-E_Busia_gamb_2016
# ...                   ...                   ...                    ...
# 19766     BF-02_colu_2016       BF-02_colu_2016  BF-02_Comoe_colu_2016
# 19767     BF-02_colu_2016       BF-02_colu_2016  BF-02_Comoe_colu_2016
# 19768     BF-02_colu_2016       BF-02_colu_2016  BF-02_Comoe_colu_2016
# 19769     BF-02_colu_2016       BF-02_colu_2016  BF-02_Comoe_colu_2016
# 19770     BF-02_colu_2016       BF-02_colu_2016  BF-02_Comoe_colu_2016
#
#            cohort_admin2_month    cohort_admin2_quarter
# 670    UG-E_Busia_gamb_2013_01  UG-E_Busia_gamb_2013_Q1
# 671    UG-E_Busia_gamb_2016_06  UG-E_Busia_gamb_2016_Q2
# 672    UG-E_Busia_gamb_2016_06  UG-E_Busia_gamb_2016_Q2
# 673    UG-E_Busia_gamb_2016_06  UG-E_Busia_gamb_2016_Q2
# 674    UG-E_Busia_gamb_2016_06  UG-E_Busia_gamb_2016_Q2
# ...                        ...                      ...
# 19766    BF-02_Comoe_colu_2016    BF-02_Comoe_colu_2016
# 19767    BF-02_Comoe_colu_2016    BF-02_Comoe_colu_2016
# 19768    BF-02_Comoe_colu_2016    BF-02_Comoe_colu_2016
# 19769    BF-02_Comoe_colu_2016    BF-02_Comoe_colu_2016
# 19770    BF-02_Comoe_colu_2016    BF-02_Comoe_colu_2016
#
# [1757 rows x 57 columns]

# %% [markdown]
# Example query to combine with other filters:

# %%
df_samples.query("country == 'Burkina Faso' and unrestricted_use")
# Out:
#           sample_id partner_sample_id       contributor       country  \
# 19466  SAMN03299607        GOUND_0022  Jacob E Crawford  Burkina Faso
# 19467  SAMN03299611        GOUND_0103  Jacob E Crawford  Burkina Faso
# 19468  SAMN03299612        GOUND_0105  Jacob E Crawford  Burkina Faso
# 19469  SAMN03299614        GOUND_0137  Jacob E Crawford  Burkina Faso
# 19470  SAMN03299615        KODOU_0009  Jacob E Crawford  Burkina Faso
# ...             ...               ...               ...           ...
# 19766  SAMN15222632              D342   Jacob Tennessen  Burkina Faso
# 19767  SAMN15222633              D343   Jacob Tennessen  Burkina Faso
# 19768  SAMN15222634              D346   Jacob Tennessen  Burkina Faso
# 19769  SAMN15222635              D347   Jacob Tennessen  Burkina Faso
# 19770  SAMN15222636              D348   Jacob Tennessen  Burkina Faso
#
#        location  year  month  latitude  longitude sex_call  ...  \
# 19466   Goundry  2008     11    12.518     -1.341      UKN  ...
# 19467   Goundry  2008     11    12.518     -1.341        F  ...
# 19468   Goundry  2008     11    12.518     -1.341      UKN  ...
# 19469   Goundry  2008     11    12.518     -1.341        F  ...
# 19470  Kodougou  2008     11    12.520     -3.607        F  ...
# ...         ...   ...    ...       ...        ...      ...  ...
# 19766  Tengrela  2016     -1    10.700     -4.800        F  ...
# 19767  Tengrela  2016     -1    10.700     -4.800        F  ...
# 19768  Tengrela  2016     -1    10.700     -4.800        F  ...
# 19769  Tengrela  2016     -1    10.700     -4.800        F  ...
# 19770  Tengrela  2016     -1    10.700     -4.800        F  ...
#
#              admin1_name admin1_iso  admin2_name       taxon  \
# 19466    Plateau Central      BF-11   Oubritenga  arabiensis
# 19467    Plateau Central      BF-11   Oubritenga  arabiensis
# 19468    Plateau Central      BF-11   Oubritenga  arabiensis
# 19469    Plateau Central      BF-11   Oubritenga  arabiensis
# 19470  Boucle du Mouhoun      BF-01        Kossi  arabiensis
# ...                  ...        ...          ...         ...
# 19766           Cascades      BF-02        Comoe    coluzzii
# 19767           Cascades      BF-02        Comoe    coluzzii
# 19768           Cascades      BF-02        Comoe    coluzzii
# 19769           Cascades      BF-02        Comoe    coluzzii
# 19770           Cascades      BF-02        Comoe    coluzzii
#
#       cohort_admin1_year cohort_admin1_month cohort_admin1_quarter  \
# 19466    BF-11_arab_2008  BF-11_arab_2008_11    BF-11_arab_2008_Q4
# 19467    BF-11_arab_2008  BF-11_arab_2008_11    BF-11_arab_2008_Q4
# 19468    BF-11_arab_2008  BF-11_arab_2008_11    BF-11_arab_2008_Q4
# 19469    BF-11_arab_2008  BF-11_arab_2008_11    BF-11_arab_2008_Q4
# 19470    BF-01_arab_2008  BF-01_arab_2008_11    BF-01_arab_2008_Q4
# ...                  ...                 ...                   ...
# 19766    BF-02_colu_2016     BF-02_colu_2016       BF-02_colu_2016
# 19767    BF-02_colu_2016     BF-02_colu_2016       BF-02_colu_2016
# 19768    BF-02_colu_2016     BF-02_colu_2016       BF-02_colu_2016
# 19769    BF-02_colu_2016     BF-02_colu_2016       BF-02_colu_2016
# 19770    BF-02_colu_2016     BF-02_colu_2016       BF-02_colu_2016
#
#                cohort_admin2_year            cohort_admin2_month  \
# 19466  BF-11_Oubritenga_arab_2008  BF-11_Oubritenga_arab_2008_11
# 19467  BF-11_Oubritenga_arab_2008  BF-11_Oubritenga_arab_2008_11
# 19468  BF-11_Oubritenga_arab_2008  BF-11_Oubritenga_arab_2008_11
# 19469  BF-11_Oubritenga_arab_2008  BF-11_Oubritenga_arab_2008_11
# 19470       BF-01_Kossi_arab_2008       BF-01_Kossi_arab_2008_11
# ...                           ...                            ...
# 19766       BF-02_Comoe_colu_2016          BF-02_Comoe_colu_2016
# 19767       BF-02_Comoe_colu_2016          BF-02_Comoe_colu_2016
# 19768       BF-02_Comoe_colu_2016          BF-02_Comoe_colu_2016
# 19769       BF-02_Comoe_colu_2016          BF-02_Comoe_colu_2016
# 19770       BF-02_Comoe_colu_2016          BF-02_Comoe_colu_2016
#
#                cohort_admin2_quarter
# 19466  BF-11_Oubritenga_arab_2008_Q4
# 19467  BF-11_Oubritenga_arab_2008_Q4
# 19468  BF-11_Oubritenga_arab_2008_Q4
# 19469  BF-11_Oubritenga_arab_2008_Q4
# 19470       BF-01_Kossi_arab_2008_Q4
# ...                              ...
# 19766          BF-02_Comoe_colu_2016
# 19767          BF-02_Comoe_colu_2016
# 19768          BF-02_Comoe_colu_2016
# 19769          BF-02_Comoe_colu_2016
# 19770          BF-02_Comoe_colu_2016
#
# [243 rows x 57 columns]

# %% [markdown]
# **Note that all sample sets in the vector observatory can be accessed and analysed at any time for public health purposes. If any terms of use apply, they may restrict the public communication of any analysis results (publication embargo) for a period of time.**
#
# If you have any questions about usage restrictions, please get in touch via support@malariagen.net.
